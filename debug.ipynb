# %%
import pandas as pd

data_1 = pd.read_excel(r"C:\Users\2026trainees86\Downloads\Credit Availability.xlsx", sheet_name="2026")
data_1
# Out:
# d:\conda_envs\pyenv\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Conditional Formatting extension is not supported and will be removed
#   warn(msg)
#     Customer Code                        Customer Name     Type Clean Credit  \
# 0            6901      Mitsubishi Chemical Corporation  Monomer         2500
# 1         2000000       MRT Resins (Thailand) Co.,Ltd.  Monomer           89
# 2         2000001     Kansai Resin (Thailand) Co.,Ltd.  Monomer           50
# 3         2000002  DIC Siam Chemical Industry Co.,Ltd.  Monomer          175
# 4         2000004               Allnex (Thailand) Ltd.  Monomer           32
# ..            ...                                  ...      ...          ...
# 471       2001077   HYDRO SANITARY (THAILAND) CO.,LTD.      CCS            6
# 472       2001078     Phatuchaiyo steel and stainless       CCS            1
# 473       2001087         Thai Metal Aluminium Co.,Ltd      CCS            2
# ...

# %%
data_1['Date'].dtypes
# Out:
# dtype('O')

# %%
data_1.columns
# Out:
# Index(['Customer Code', 'Customer Name', 'Type', 'Clean Credit',
#        'Current Debt (Million Baht)', 'Current Debt (Million Baht).1',
#        'Est. further amount ', 'Est. Debt', 'Date', 'Estimate Amount', 'CCS',
#        'Price', 'MMA', 'Price.1', 'nBMA', 'Price.2', 'iBMA', 'Price.3', 'MAA',
#        'Price.4', 'Higher Ester', 'Price.5'],
#       dtype='str')

# %%
import pandas as pd

data_2 = pd.read_excel(r"C:\Users\2026trainees86\Downloads\Credit Availability.xlsx", sheet_name="2023")
data_2
# Out:
#       Customer Code                     Customer Name     Type  \
# 0            6901.0   Mitsubishi Chemical Corporation  Monomer
# 1         2000000.0    MRT Resins (Thailand) Co.,Ltd.  Monomer
# 2         2000001.0  Kansai Resin (Thailand) Co.,Ltd.  Monomer
# 3         2000002.0   Siam Chemical Industry Co.,Ltd.  Monomer
# 4         2000004.0            Allnex (Thailand) Ltd.  Monomer
# ...             ...                               ...      ...
# 2042      2000783.0           GTECH PRODUCTS CO., LTD      CCS
# 2043      2000786.0                GTECH OHM CO.,LTD.      CCS
# 2044      2000787.0                       GTS Variety      CCS
# 2045      2000788.0            GTECH STATION CO.,LTD.      CCS
# 2046      2000762.0                  อ.นำแสงไทย จำกัด      CCS
#
#       Clean credit (MB)  Current Debt (Million Baht)  Est. further amount   \
# 0                3400.0                      563.274               0.00000
# ...

# %%
data_2['Date'].dtypes
# Out:
# dtype('<M8[us]')

# %%
data_2.columns
# Out:
# Index(['Customer Code', 'Customer Name', 'Type', 'Clean credit (MB)',
#        'Current Debt (Million Baht)', 'Est. further amount ', 'Date',
#        'Estimate Amount', 'CCS', 'Price', 'MMA', 'Price.1', 'nBMA', 'Price.2',
#        'iBMA', 'Price.3', 'MAA', 'Price.4', 'Higher Ester', 'Price.5'],
#       dtype='str')
